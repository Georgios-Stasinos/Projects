# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
df1=pd.read_csv('/content/gdrive/MyDrive/owid-co2-data.csv')

# %%
df1
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3769828.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3787706.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3806634.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3825655.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
df2=pd.read_csv('/content/gdrive/MyDrive/urban-and-rural-population.csv')

# %%
df2
# Out:
#             Entity Code  Year  Urban population  Rural population
# 0      Afghanistan  AFG  1960            755835           8241132
# 1      Afghanistan  AFG  1961            796271           8373135
# 2      Afghanistan  AFG  1962            839385           8512057
# 3      Afghanistan  AFG  1963            885227           8657973
# 4      Afghanistan  AFG  1964            934134           8810638
# ...            ...  ...   ...               ...               ...
# 13983     Zimbabwe  ZWE  2016           4531238           9499100
# 13984     Zimbabwe  ZWE  2017           4589452           9647147
# 13985     Zimbabwe  ZWE  2018           4650597           9788215
# 13986     Zimbabwe  ZWE  2019           4717307           9928166
# 13987     Zimbabwe  ZWE  2020           4792105          10070822
#
# [13988 rows x 5 columns]

# %%
df2 = df2.rename(columns={"Year": "year","Entity": "country","Code": "iso_code"})

# %% [markdown]
# # ChatGPT list

# %%
europe_country_codes = [
  'ALB', 'AND', 'AUT', 'BLR', 'BEL', 'BIH', 'BGR', 'HRV', 'CYP', 'CZE', 'DNK', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'LVA', 'LIE', 'LTU', 'LUX', 'MLT', 'MDA', 'MCO', 'MNE', 'NLD', 'MKD', 'NOR', 'POL', 
  'PRT', 'ROU', 'RUS', 'SMR', 'SRB', 'SVK', 'SVN', 'ESP', 'SWE', 'CHE', 'TUR', 'UKR', 'GBR'
]

# %%
merged_df = pd.merge(df1.drop('population',axis=1),df2[['iso_code', 'Urban population','Rural population', 'year']],on = ['iso_code', 'year'])

# %% [markdown]
# # nan difference

# %%
merged_df
# Out:
#            country  year iso_code           gdp  cement_co2  \
# 0      Afghanistan  1960      AFG  1.303325e+10       0.018
# 1      Afghanistan  1961      AFG  1.314629e+10       0.022
# 2      Afghanistan  1962      AFG  1.336763e+10       0.029
# 3      Afghanistan  1963      AFG  1.363030e+10       0.051
# 4      Afghanistan  1964      AFG  1.387050e+10       0.062
# ...            ...   ...      ...           ...         ...
# 38248     Zimbabwe  2016      ZWE  2.096179e+10       0.461
# 38249     Zimbabwe  2017      ZWE  2.194784e+10       0.469
# 38250     Zimbabwe  2018      ZWE  2.271535e+10       0.558
# 38251     Zimbabwe  2019      ZWE           NaN       0.570
# 38252     Zimbabwe  2020      ZWE           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  \
# 0                      0.002   0.414           0.029            7.623
# 1                      0.002   0.491           0.077           18.583
# ...

# %% [markdown]
# #Decided to keep data of European countries in order to create a more relevant and manageable dataset.

# %%
df3=merged_df[(merged_df['iso_code'].isin(europe_country_codes)) & (merged_df['year']>=1980)]

# %%
df3
# Out:
#               country  year iso_code           gdp  cement_co2  \
# 25799         Albania  1980      ALB  9.993753e+09       0.503
# 25800         Albania  1981      ALB  1.024871e+10       0.396
# 25801         Albania  1982      ALB  1.051711e+10       0.419
# 25802         Albania  1983      ALB  1.079598e+10       0.424
# 25803         Albania  1984      ALB  1.108009e+10       0.436
# ...               ...   ...      ...           ...         ...
# 37638  United Kingdom  2016      GBR  2.460057e+12       4.553
# 37639  United Kingdom  2017      GBR  2.506604e+12       4.410
# 37640  United Kingdom  2018      GBR  2.540210e+12       4.364
# 37641  United Kingdom  2019      GBR           NaN       4.448
# 37642  United Kingdom  2020      GBR           NaN       3.900
#
#        cement_co2_per_capita      co2  co2_growth_abs  co2_growth_prct  \
# 25799                  0.171    5.171          -2.413          -31.819
# ...

# %% [markdown]
# decided to keep

# %%
df3=df3[['country','iso_code', 'year','Urban population', 'Rural population','gdp','co2_including_luc']]

# %%
df3
# Out:
#               country iso_code  year  Urban population  Rural population  \
# 25799         Albania      ALB  1980            902120           1769877
# 25800         Albania      ALB  1981            927513           1798543
# 25801         Albania      ALB  1982            954645           1829633
# 25802         Albania      ALB  1983            982645           1861315
# 25803         Albania      ALB  1984           1011235           1893194
# ...               ...      ...   ...               ...               ...
# 37638  United Kingdom      GBR  2016          54382825          11228768
# 37639  United Kingdom      GBR  2017          54923317          11135542
# 37640  United Kingdom      GBR  2018          55426598          11033746
# 37641  United Kingdom      GBR  2019          55909924          10926403
# 37642  United Kingdom      GBR  2020          56395647          10819646
#
#                 gdp  co2_including_luc
# 25799  9.993753e+09              8.139
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
df3
# Out:
#               country iso_code  year  Urban population  Rural population  \
# 25799         Albania      ALB  1980            902120           1769877
# 25800         Albania      ALB  1981            927513           1798543
# 25801         Albania      ALB  1982            954645           1829633
# 25802         Albania      ALB  1983            982645           1861315
# 25803         Albania      ALB  1984           1011235           1893194
# ...               ...      ...   ...               ...               ...
# 37638  United Kingdom      GBR  2016          54382825          11228768
# 37639  United Kingdom      GBR  2017          54923317          11135542
# 37640  United Kingdom      GBR  2018          55426598          11033746
# 37641  United Kingdom      GBR  2019          55909924          10926403
# 37642  United Kingdom      GBR  2020          56395647          10819646
#
#                    gdp  co2_including_luc
# 25799    9993752576.00               8.14
# ...

# %% [markdown]
# time series popultaion gdp co2
